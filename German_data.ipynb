# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\JAY\Downloads\german.data")
df.to_csv(r'C:\Users\JAY\Downloads\german.data',index=None)

# %%
column_names = ['CkgAcct', 'Duration', 'CreditHistory', 'Purpose', 'CreditAmt', 'Savings', 'EmploymentTime',
               'PctIncome', 'PersStatus', 'OtherDebts', 'ResidenceSince', 'Property',
               'AgeYrs', 'OtherLoan', 'Housing', 'NumCredits', 'Job', 'FamSize', 'Telephone',
               'Foriegn', 'LoanGood']
df = pd.read_csv(r'C:\Users\JAY\Downloads\german.data',names=column_names, sep=' ')

# %%
df.head()
# Out:
#   CkgAcct  Duration CreditHistory Purpose  CreditAmt Savings EmploymentTime  \
# 0     A11         6           A34     A43       1169     A65            A75
# 1     A12        48           A32     A43       5951     A61            A73
# 2     A14        12           A34     A46       2096     A61            A74
# 3     A11        42           A32     A42       7882     A61            A74
# 4     A11        24           A33     A40       4870     A61            A73
#
#    PctIncome PersStatus OtherDebts  ...  Property AgeYrs  OtherLoan Housing  \
# 0          4        A93       A101  ...      A121     67       A143    A152
# 1          2        A92       A101  ...      A121     22       A143    A152
# 2          2        A93       A101  ...      A121     49       A143    A152
# 3          2        A93       A103  ...      A122     45       A143    A153
# 4          3        A93       A101  ...      A124     53       A143    A153
#
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.columns
# Out:
# Index(['CkgAcct', 'Duration', 'CreditHistory', 'Purpose', 'CreditAmt',
#        'Savings', 'EmploymentTime', 'PctIncome', 'PersStatus', 'OtherDebts',
#        'ResidenceSince', 'Property', 'AgeYrs', 'OtherLoan', 'Housing',
#        'NumCredits', 'Job', 'FamSize', 'Telephone', 'Foriegn', 'LoanGood'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CkgAcct           object
# Duration           int64
# CreditHistory     object
# Purpose           object
# CreditAmt          int64
# Savings           object
# EmploymentTime    object
# PctIncome          int64
# PersStatus        object
# OtherDebts        object
# ResidenceSince     int64
# Property          object
# AgeYrs             int64
# OtherLoan         object
# Housing           object
# NumCredits         int64
# Job               object
# FamSize            int64
# Telephone         object
# Foriegn           object
# LoanGood           int64
# dtype: object

# %%
df["CreditHistory"] = df["CreditHistory"].astype('category')
df.dtypes
# Out:
# CkgAcct             object
# Duration             int64
# CreditHistory     category
# Purpose             object
# CreditAmt            int64
# Savings             object
# EmploymentTime      object
# PctIncome            int64
# PersStatus          object
# OtherDebts          object
# ResidenceSince       int64
# Property            object
# AgeYrs               int64
# OtherLoan           object
# Housing             object
# NumCredits           int64
# Job                 object
# FamSize              int64
# Telephone           object
# Foriegn             object
# LoanGood             int64
# dtype: object

# %%
df["Credithist_cat"] = df["CreditHistory"].cat.codes
df.head()


##A30: 0: no credits taken/ all credits paid back duly
##A31:1 : all credits at this bank paid back duly
##A32 :2: existing credits paid back duly till now
#A33 :3: delay in paying off in the past
#A34:4 : critical account/ other credits existing (not at this bank)
# Out:
#   CkgAcct  Duration CreditHistory Purpose  CreditAmt Savings EmploymentTime  \
# 0     A11         6           A34     A43       1169     A65            A75
# 1     A12        48           A32     A43       5951     A61            A73
# 2     A14        12           A34     A46       2096     A61            A74
# 3     A11        42           A32     A42       7882     A61            A74
# 4     A11        24           A33     A40       4870     A61            A73
#
#    PctIncome PersStatus OtherDebts  ...  AgeYrs OtherLoan  Housing NumCredits  \
# 0          4        A93       A101  ...      67      A143     A152          2
# 1          2        A92       A101  ...      22      A143     A152          1
# 2          2        A93       A101  ...      49      A143     A152          1
# 3          2        A93       A103  ...      45      A143     A153          1
# 4          3        A93       A101  ...      53      A143     A153          2
#
# ...

# %%
del df['CreditHistory']

# %%
df.head()
# Out:
#   CkgAcct  Duration Purpose  CreditAmt Savings EmploymentTime  PctIncome  \
# 0     A11         6     A43       1169     A65            A75          4
# 1     A12        48     A43       5951     A61            A73          2
# 2     A14        12     A46       2096     A61            A74          2
# 3     A11        42     A42       7882     A61            A74          2
# 4     A11        24     A40       4870     A61            A73          3
#
#   PersStatus OtherDebts  ResidenceSince  ... AgeYrs  OtherLoan Housing  \
# 0        A93       A101               4  ...     67       A143    A152
# 1        A92       A101               2  ...     22       A143    A152
# 2        A93       A101               3  ...     49       A143    A152
# 3        A93       A103               4  ...     45       A143    A153
# 4        A93       A101               4  ...     53       A143    A153
#
#   NumCredits   Job FamSize  Telephone Foriegn LoanGood  Credithist_cat
# ...

# %%
df["CkgAcct"] = df["CkgAcct"].astype('category')
df.dtypes
# Out:
# CkgAcct           category
# Duration             int64
# Purpose             object
# CreditAmt            int64
# Savings             object
# EmploymentTime      object
# PctIncome            int64
# PersStatus          object
# OtherDebts          object
# ResidenceSince       int64
# Property            object
# AgeYrs               int64
# OtherLoan           object
# Housing             object
# NumCredits           int64
# Job                 object
# FamSize              int64
# Telephone           object
# Foriegn             object
# LoanGood             int64
# Credithist_cat        int8
# dtype: object

# %%
df["CkgAcct"] = df["CkgAcct"].cat.codes
df.head()

##A11 :0: < 0 DM
##A12 :1: 0 <= ..< 200 DM
##A13 : 2:... >= 200 DM / salary assignments for at least 1 year
##A14 : 3:no checking account
# Out:
#    CkgAcct  Duration Purpose  CreditAmt Savings EmploymentTime  PctIncome  \
# 0        0         6     A43       1169     A65            A75          4
# 1        1        48     A43       5951     A61            A73          2
# 2        3        12     A46       2096     A61            A74          2
# 3        0        42     A42       7882     A61            A74          2
# 4        0        24     A40       4870     A61            A73          3
#
#   PersStatus OtherDebts  ResidenceSince  ... AgeYrs  OtherLoan Housing  \
# 0        A93       A101               4  ...     67       A143    A152
# 1        A92       A101               2  ...     22       A143    A152
# 2        A93       A101               3  ...     49       A143    A152
# 3        A93       A103               4  ...     45       A143    A153
# 4        A93       A101               4  ...     53       A143    A153
#
#   NumCredits   Job FamSize  Telephone Foriegn LoanGood  Credithist_cat
# ...

# %%
df["Purpose"] = df["Purpose"].astype('category')
df.dtypes
# Out:
# CkgAcct               int8
# Duration             int64
# Purpose           category
# CreditAmt            int64
# Savings             object
# EmploymentTime      object
# PctIncome            int64
# PersStatus          object
# OtherDebts          object
# ResidenceSince       int64
# Property            object
# AgeYrs               int64
# OtherLoan           object
# Housing             object
# NumCredits           int64
# Job                 object
# FamSize              int64
# Telephone           object
# Foriegn             object
# LoanGood             int64
# Credithist_cat        int8
# dtype: object

# %%
df["Purpose"] = df["Purpose"].cat.codes
df.head()

##A40:0 : car (new)
##A41 :1: car (used)
##A42 :2: furniture/equipment
##A43 :3: radio/television
##A44 :4: domestic appliances
##A45 :5: repairs
##A46 :6: education
##A47 :7: (vacation - does not exist?)
##A48 :8: retraining
##A49 :9: business
##A410 :10: others
# Out:
#    CkgAcct  Duration  Purpose  CreditAmt Savings EmploymentTime  PctIncome  \
# 0        0         6        4       1169     A65            A75          4
# 1        1        48        4       5951     A61            A73          2
# 2        3        12        7       2096     A61            A74          2
# 3        0        42        3       7882     A61            A74          2
# 4        0        24        0       4870     A61            A73          3
#
#   PersStatus OtherDebts  ResidenceSince  ... AgeYrs  OtherLoan Housing  \
# 0        A93       A101               4  ...     67       A143    A152
# 1        A92       A101               2  ...     22       A143    A152
# 2        A93       A101               3  ...     49       A143    A152
# 3        A93       A103               4  ...     45       A143    A153
# 4        A93       A101               4  ...     53       A143    A153
#
#   NumCredits   Job FamSize  Telephone Foriegn LoanGood  Credithist_cat
# ...

# %%
df.dtypes
# Out:
# CkgAcct             int8
# Duration           int64
# Purpose             int8
# CreditAmt          int64
# Savings           object
# EmploymentTime    object
# PctIncome          int64
# PersStatus        object
# OtherDebts        object
# ResidenceSince     int64
# Property          object
# AgeYrs             int64
# OtherLoan         object
# Housing           object
# NumCredits         int64
# Job               object
# FamSize            int64
# Telephone         object
# Foriegn           object
# LoanGood           int64
# Credithist_cat      int8
# dtype: object

# %%
cat_features = ['PersStatus','OtherDebts','Property','OtherLoan' ,'Housing','Job','Telephone','Foriegn']

for features in cat_features :
    df[features] = df[features].astype('category')
    df[features] = df[features].cat.codes

# %%
cat = ['Purpose','Savings','EmploymentTime']

for features in cat:
    df[features] = df[features].astype('category')
    df[features] = df[features].cat.codes

# %%
df.head()
# Out:
#    CkgAcct  Duration  Purpose  CreditAmt  Savings  EmploymentTime  PctIncome  \
# 0        0         6        4       1169        4               4          4
# 1        1        48        4       5951        0               2          2
# 2        3        12        7       2096        0               3          2
# 3        0        42        3       7882        0               3          2
# 4        0        24        0       4870        0               2          3
#
#    PersStatus  OtherDebts  ResidenceSince  ...  AgeYrs  OtherLoan  Housing  \
# 0           2           0               4  ...      67          2        1
# 1           1           0               2  ...      22          2        1
# 2           2           0               3  ...      49          2        1
# 3           2           2               4  ...      45          2        2
# 4           2           0               4  ...      53          2        2
#
# ...

# %%
df['LoanGood'] = df['LoanGood'].replace(2 , 0)

# %%
df.head()
# Out:
#    CkgAcct  Duration  Purpose  CreditAmt  Savings  EmploymentTime  PctIncome  \
# 0        0         6        4       1169        4               4          4
# 1        1        48        4       5951        0               2          2
# 2        3        12        7       2096        0               3          2
# 3        0        42        3       7882        0               3          2
# 4        0        24        0       4870        0               2          3
#
#    PersStatus  OtherDebts  ResidenceSince  ...  AgeYrs  OtherLoan  Housing  \
# 0           2           0               4  ...      67          2        1
# 1           1           0               2  ...      22          2        1
# 2           2           0               3  ...      49          2        1
# 3           2           2               4  ...      45          2        2
# 4           2           0               4  ...      53          2        2
#
# ...

# %%
df.describe()
# Out:
#            CkgAcct     Duration      Purpose     CreditAmt      Savings  \
# count  1000.000000  1000.000000  1000.000000   1000.000000  1000.000000
# mean      1.577000    20.903000     3.277000   3271.258000     1.105000
# std       1.257638    12.058814     2.739302   2822.736876     1.580023
# min       0.000000     4.000000     0.000000    250.000000     0.000000
# 25%       0.000000    12.000000     1.000000   1365.500000     0.000000
# 50%       1.000000    18.000000     3.000000   2319.500000     0.000000
# 75%       3.000000    24.000000     4.000000   3972.250000     2.000000
# max       3.000000    72.000000     9.000000  18424.000000     4.000000
#
#        EmploymentTime    PctIncome  PersStatus   OtherDebts  ResidenceSince  \
# count     1000.000000  1000.000000  1000.00000  1000.000000     1000.000000
# mean         2.384000     2.973000     1.68200     0.145000        2.845000
# std          1.208306     1.118715     0.70808     0.477706        1.103718
# ...

# %%
df.columns
# Out:
# Index(['CkgAcct', 'Duration', 'Purpose', 'CreditAmt', 'Savings',
#        'EmploymentTime', 'PctIncome', 'PersStatus', 'OtherDebts',
#        'ResidenceSince', 'Property', 'AgeYrs', 'OtherLoan', 'Housing',
#        'NumCredits', 'Job', 'FamSize', 'Telephone', 'Foriegn', 'LoanGood',
#        'Credithist_cat'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import *
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop('LoanGood',axis =1)


y = df['LoanGood']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state =1)

# %%
pipe = make_pipeline(StandardScaler(),LogisticRegression())

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
train_proba = pipe.predict_proba(x_train)[:,1]
test_proba = pipe.predict_proba(x_test)[:,1]

# %%
PrecisionRecallDisplay.from_predictions(y_train,train_proba)

# %%
PrecisionRecallDisplay.from_predictions(y_test,test_proba)

# %%
RocCurveDisplay.from_predictions(y_train,train_proba)
RocCurveDisplay.from_predictions(y_test,test_proba)

# %%
threshold = 0.5
train_pred = np.where(train_proba > threshold,1,0)
test_pred = np.where(test_proba > threshold ,1,0)
print('Train')
print(classification_report(y_train,train_pred))
print('Test')
print(classification_report(y_test,test_pred))
# Out:
# Train
#               precision    recall  f1-score   support
#
#            0       0.66      0.50      0.57       241
#            1       0.80      0.89      0.84       559
#
#     accuracy                           0.77       800
#    macro avg       0.73      0.69      0.70       800
# weighted avg       0.76      0.77      0.76       800
#
# Test
#               precision    recall  f1-score   support
#
#            0       0.66      0.42      0.52        59
#            1       0.79      0.91      0.84       141
#
#     accuracy                           0.77       200
#    macro avg       0.72      0.67      0.68       200
# weighted avg       0.75      0.77      0.75       200

# %%
df.LoanGood.value_counts()
# Out:
# 1    700
# 0    300
# Name: LoanGood, dtype: int64
